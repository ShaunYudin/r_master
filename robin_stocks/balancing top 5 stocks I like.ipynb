# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import robin_stocks as r
import numpy as np
import time

# %%
login = r.login('shaunyudin@gmail.com','YQ9BNy3!&hN4yq^x')

# %%
while True:
    positions_data = pd.DataFrame(r.build_holdings()) 
    df = pd.DataFrame
    
    #####ability to adjust stocks
    
    stocks = ['BIDU', 'BRK.B', 'FB', 'GOOGL', 'AMZN']
    
    ####
    
    df1 = df(positions_data.loc['price': 'quantity', stocks]).astype(float).round(1)

    df1.loc['priceqsum'] = [df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]
    
    ###ability to adjust total amount of money invested, e.g. add 10k or something
    maxv = 95000
    minv = 30000
    if sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]) > maxv:
        current_t_value = maxv
    elif sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]) < minv:
        current_t_value = minv
    else:
        current_t_value = sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns])   
    
    
    ##### weight goals
    
    df1.loc['weightgoal'] = ['.2', '.2', '.2', '.2', '.2']
    
    #####
    
    
    df1.loc['currentweight'] = [df1.loc['priceqsum', x] / current_t_value for x in df1.columns]
    

    
    
    
    ###creating all open order
    open_ord_df = pd.DataFrame(r.get_all_open_orders())
    open_ord_df.loc[:,'stock'] = [r.get_instrument_by_url(open_ord_df.loc[i, 'instrument'])['symbol']  for i in open_ord_df.index]

    print(df1)
    print(current_t_value)
    print(sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]))
    for stocks in df1.columns:
        if open_ord_df[open_ord_df.stock == stocks].size == 0:
            absw = abs(float(df1.loc['weightgoal', stocks]) - float(df1.loc['currentweight', stocks]))


            stock_price = float(df1.loc['price', stocks])
            to_buy = (absw * current_t_value) / stock_price

            weightgoal = float(df1.loc['weightgoal', stocks])
            currentweight = float(df1.loc['currentweight', stocks])
            if abs(to_buy)  > .7:
                if round(weightgoal,4) < round(currentweight,4):
                    print(r.order_sell_market(stocks, round((to_buy),0)))
                else:
                    print(r.order_buy_market(stocks, round((to_buy),0)))
            else:
                print(stocks + " not enough to trade")
        else:
            print("already have order for stock " + str(stocks))
    time.sleep(80)
# Out:
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1887
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5661
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1887
# 30000
# 25129.6
# already have order for stock BIDU
# {'id': 'bbabf20d-8c35-49ae-9c12-efa2b4e0c887', 'ref_id': '2d872c59-4cf3-48a9-825b-bcb1ca054e4f', 'url': 'https://api.robinhood.com/orders/bbabf20d-8c35-49ae-9c12-efa2b4e0c887/', 'account': 'https://api.robinhood.com/accounts/5QW39286/', 'position': 'https://api.robinhood.com/accounts/5QW39286/positions/a4f0cca4-79dc-4297-9c02-5bce1909cd4b/', 'cancel': 'https://api.robinhood.com/orders/bbabf20d-8c35-49ae-9c12-efa2b4e0c887/cancel/', 'instrument': 'https://api.robinhood.com/instruments/a4f0cca4-79dc-4297-9c02-5bce1909cd4b/', 'cumulative_quantity': '0.00000000', 'average_price': None, 'fees': '0.00', 'state': 'unconfirmed', 'type': 'market', 'side': 'buy', 'time_in_force': 'gtc', 'trigger': 'immediate', 'price': '230.00000000', 'stop_price': None, 'quantity': '4.00000000', 'reject_reason': None, 'created_at': '2020-01-23T13:54:44.721573Z', 'updated_at': '2020-01-23T13:54:44.729444Z', 'last_transaction_at': '2020-01-23T13:54:44.721573Z', 'executions': [], 'extended_hours': False, 'override_dtbp_checks': False, 'override_day_trade_checks': False, 'response_category': None, 'stop_triggered_at': None, 'last_trail_price': None, 'last_trail_price_updated_at': None}
# {'id': 'baddd4db-7c82-4f02-9b99-a0b8ddd22153', 'ref_id': 'fcbe4539-0422-4fcd-a106-ac0931bb6e26', 'url': 'https://api.robinhood.com/orders/baddd4db-7c82-4f02-9b99-a0b8ddd22153/', 'account': 'https://api.robinhood.com/accounts/5QW39286/', 'position': 'https://api.robinhood.com/accounts/5QW39286/positions/ebab2398-028d-4939-9f1d-13bf38f81c50/', 'cancel': 'https://api.robinhood.com/orders/baddd4db-7c82-4f02-9b99-a0b8ddd22153/cancel/', 'instrument': 'https://api.robinhood.com/instruments/ebab2398-028d-4939-9f1d-13bf38f81c50/', 'cumulative_quantity': '0.00000000', 'average_price': None, 'fees': '0.00', 'state': 'unconfirmed', 'type': 'market', 'side': 'buy', 'time_in_force': 'gtc', 'trigger': 'immediate', 'price': '220.25000000', 'stop_price': None, 'quantity': '4.00000000', 'reject_reason': None, 'created_at': '2020-01-23T13:54:45.228501Z', 'updated_at': '2020-01-23T13:54:45.236446Z', 'last_transaction_at': '2020-01-23T13:54:45.228501Z', 'executions': [], 'extended_hours': False, 'override_dtbp_checks': False, 'override_day_trade_checks': False, 'response_category': None, 'stop_triggered_at': None, 'last_trail_price': None, 'last_trail_price_updated_at': None}
# {'id': '5cb763eb-92f4-4a46-b3cc-afc1f59710b4', 'ref_id': '524dc137-1088-4caf-a302-afd3bbe825dd', 'url': 'https://api.robinhood.com/orders/5cb763eb-92f4-4a46-b3cc-afc1f59710b4/', 'account': 'https://api.robinhood.com/accounts/5QW39286/', 'position': 'https://api.robinhood.com/accounts/5QW39286/positions/54db869e-f7d5-45fb-88f1-8d7072d4c8b2/', 'cancel': 'https://api.robinhood.com/orders/5cb763eb-92f4-4a46-b3cc-afc1f59710b4/cancel/', 'instrument': 'https://api.robinhood.com/instruments/54db869e-f7d5-45fb-88f1-8d7072d4c8b2/', 'cumulative_quantity': '0.00000000', 'average_price': None, 'fees': '0.00', 'state': 'unconfirmed', 'type': 'market', 'side': 'buy', 'time_in_force': 'gtc', 'trigger': 'immediate', 'price': '1484.17000000', 'stop_price': None, 'quantity': '1.00000000', 'reject_reason': None, 'created_at': '2020-01-23T13:54:45.683813Z', 'updated_at': '2020-01-23T13:54:45.692083Z', 'last_transaction_at': '2020-01-23T13:54:45.683813Z', 'executions': [], 'extended_hours': False, 'override_dtbp_checks': False, 'override_day_trade_checks': False, 'response_category': None, 'stop_triggered_at': None, 'last_trail_price': None, 'last_trail_price_updated_at': None}
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1887
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5661
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1887
# 30000
# 25129.6
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Additional pages exist but could not be loaded.
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1887
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5661
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1887
# 30000
# 25129.6
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1885
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5655
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1885
# 30000
# 25123.6
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1885
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5655
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1885
# 30000
# 25123.6
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B       FB    GOOGL    AMZN
# price             132.2       230    220.2   1484.2    1885
# quantity             37        22       23        3       3
# priceqsum        4891.4      5060   5064.6   4452.6    5655
# weightgoal           .2        .2       .2       .2      .2
# currentweight  0.163047  0.168667  0.16882  0.14842  0.1885
# 30000
# 25123.6
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B        FB    GOOGL    AMZN
# price             132.2       230     220.3   1484.2    1885
# quantity             37        22        23        3       3
# priceqsum        4891.4      5060    5066.9   4452.6    5655
# weightgoal           .2        .2        .2       .2      .2
# currentweight  0.163047  0.168667  0.168897  0.14842  0.1885
# 30000
# 25125.9
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B        FB    GOOGL    AMZN
# price             132.4       230     220.3   1484.2    1885
# quantity             37        22        23        3       3
# priceqsum        4898.8      5060    5066.9   4452.6    5655
# weightgoal           .2        .2        .2       .2      .2
# currentweight  0.163293  0.168667  0.168897  0.14842  0.1885
# 30000
# 25133.300000000003
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B        FB    GOOGL    AMZN
# price             132.4       230     220.3   1484.2    1885
# quantity             37        22        23        3       3
# priceqsum        4898.8      5060    5066.9   4452.6    5655
# weightgoal           .2        .2        .2       .2      .2
# currentweight  0.163293  0.168667  0.168897  0.14842  0.1885
# 30000
# 25133.300000000003
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B        FB    GOOGL    AMZN
# price             132.4       230     220.3   1480.4    1885
# quantity             37        22        23        3       3
# priceqsum        4898.8      5060    5066.9   4441.2    5655
# weightgoal           .2        .2        .2       .2      .2
# currentweight  0.163293  0.168667  0.168897  0.14804  0.1885
# 30000
# 25121.9
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade
# Found Additional pages.
# Loading page 2 ...
# Loading page 3 ...
# Loading page 4 ...
# Loading page 5 ...
# Loading page 6 ...
# Loading page 7 ...
# Loading page 8 ...
# Loading page 9 ...
# Loading page 10 ...
# Loading page 11 ...
# Loading page 12 ...
# Loading page 13 ...
# Loading page 14 ...
# Loading page 15 ...
# Loading page 16 ...
# Loading page 17 ...
# Loading page 18 ...
# Loading page 19 ...
# Loading page 20 ...
# Loading page 21 ...
# Loading page 22 ...
# Loading page 23 ...
# Loading page 24 ...
# Loading page 25 ...
# Loading page 26 ...
# Loading page 27 ...
# Loading page 28 ...
# Loading page 29 ...
# Loading page 30 ...
# Loading page 31 ...
# Loading page 32 ...
# Loading page 33 ...
# Loading page 34 ...
# Loading page 35 ...
# Loading page 36 ...
# Loading page 37 ...
# Loading page 38 ...
# Loading page 39 ...
# Loading page 40 ...
# Loading page 41 ...
# Loading page 42 ...
# Loading page 43 ...
# Loading page 44 ...
# Loading page 45 ...
# Loading page 46 ...
# Loading page 47 ...
# Loading page 48 ...
# Loading page 49 ...
# Loading page 50 ...
# Loading page 51 ...
# Loading page 52 ...
# Loading page 53 ...
# Loading page 54 ...
# Loading page 55 ...
# Loading page 56 ...
# Loading page 57 ...
# Loading page 58 ...
#                    BIDU     BRK.B        FB    GOOGL    AMZN
# price             132.4       230     220.3   1480.4    1885
# quantity             37        22        23        3       3
# priceqsum        4898.8      5060    5066.9   4441.2    5655
# weightgoal           .2        .2        .2       .2      .2
# currentweight  0.163293  0.168667  0.168897  0.14804  0.1885
# 30000
# 25121.9
# already have order for stock BIDU
# already have order for stock BRK.B
# already have order for stock FB
# already have order for stock GOOGL
# AMZN not enough to trade

# %%
round(weightgoal,3) != round(currentweight,3)

# %%
absw

# %%
positions_data = pd.DataFrame(r.build_holdings())
df = pd.DataFrame
stocks = ['BRK.B', 'FB', 'AMZN']
df1 = df(positions_data.loc['price': 'quantity', stocks]).astype(float).round(1)
df1

# %%
[df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]

# %%
df1.loc['priceqsum'] = [df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]

# %%
df1.loc['priceqsum'] = [df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]
current_t_value = sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns])
current_t_value

# %%
open_ord_df = pd.DataFrame(r.get_all_open_orders())

# %%
open_ord_df.loc[1, 'instrument']

# %%
open_ord_df.loc[:,'stock'] = [r.get_instrument_by_url(open_ord_df.loc[i, 'instrument'])['symbol']  for i in open_ord_df.index]

# %%
open_ord_df.loc[:,'stock']

# %%
open_ord_df.loc[:,'stock']

# %%
r.get_instrument_by_url(open_ord_df.loc[0, 'instrument'])['symbol']

# %%
open_ord_df.columns

# %%
open_ord_df[open_ord_df.stock == 'BRK.B']

# %%
    positions_data = pd.DataFrame(r.build_holdings())
    df = pd.DataFrame
    
    #####ability to adjust stocks
    
    stocks = ['BRK.B', 'FB', 'GOOGL', 'AMZN']
    
    ####
    
    df1 = df(positions_data.loc['price': 'quantity', stocks]).astype(float).round(1)

    df1.loc['priceqsum'] = [df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]
   
    ###ability to adjust total amount of money invested, e.g. add 10k or something
    current_t_value = sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns])
    
    
    ##### weight goals
    
    df1.loc['weightgoal'] = ['.37', '.37', '16', '.10']

# %%
    df1.loc['currentweight'] = [df1.loc['priceqsum', x] / df1.loc['priceqsum'].sum() for x in df1.columns]
    df1

# %%
while True:
    positions_data = pd.DataFrame(r.build_holdings()) 
    df = pd.DataFrame
    
    #####ability to adjust stocks
    
    stocks = ['BIDU', 'BRK.B', 'FB', 'GOOGL', 'AMZN']
    
    ####
    
    df1 = df(positions_data.loc['price': 'quantity', stocks]).astype(float).round(1)

    df1.loc['priceqsum'] = [df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns]
   
    ###ability to adjust total amount of money invested, e.g. add 10k or something
    current_t_value = sum([df1.loc['price', x] * df1.loc['quantity',x] for x in df1.columns])
    
    
    ##### weight goals
    
    df1.loc['weightgoal'] = ['.1', '.32', '.32', '.16', '.10']
    
    #####
    
    
    df1.loc['currentweight'] = [df1.loc['priceqsum', x] / df1.loc['priceqsum'].sum() for x in df1.columns]
    print(df1)

    
    
    
    ###creating all open order
    open_ord_df = pd.DataFrame(r.get_all_open_orders())
    open_ord_df.loc[:,'stock'] = [r.get_instrument_by_url(open_ord_df.loc[i, 'instrument'])['symbol']  for i in open_ord_df.index]


    for stocks in df1.columns:
        if open_ord_df[open_ord_df.stock == stocks].size == 0:
            absw = abs(float(df1.loc['weightgoal', stocks]) - float(df1.loc['currentweight', stocks]))


            stock_price = float(df1.loc['price', stocks])
            to_buy = (absw * current_t_value) / stock_price

            weightgoal = float(df1.loc['weightgoal', stocks])
            currentweight = float(df1.loc['currentweight', stocks])
            if stock_price / absw  > 1:
                if (weightgoal < currentweight):
                    print(r.order_sell_market(stocks, round(to_buy,0)))
                else:
                    print(r.order_buy_market(stocks, round(to_buy,0)))
            else:
                print(stocks + "not enough to trade")
        else:
            print("already have order for stock " + str(stocks))
    time.sleep(200)

# %%
df1.loc['weightgoal', stocks]

# %%
50000000/60

# %%
float(df1.loc['weightgoal', stocks])

# %%
sum = pd.DataFrame(np.dot(df1[:1].astype('float'), df1[:3].astype('float')), index = test,  columns = df1.columns)

# %%
#current total value of portfolio
test = ['sum_prod']
sum = pd.DataFrame(np.dot(df1[:1].astype('float'), df1[:3].astype('float')), index = test,  columns = df1.columns)
total_current = pd.DataFrame(sum.T.sum(), index = ['total_curret'])
##taking the sum product of current holdings
df1 = df1.append(sum)
###finding the current value of total holdings

##df1
df3 = pd.DataFrame(df1.loc['sum_prod'].sum(), index = ['total_current'], columns = df1.columns)
df1 = df1.append(df3)

# %%
##goal of 60% 40% for each
##for i in 
df1.loc['current'] = df1.loc['sum_prod'].astype(float).round(1) / df1.loc['total_current'].astype(float).round(1)

# %%
df1.loc['weightings'] = ['.4', '.4', '.2']
df1

# %%
for stock in df1.columns:
    if df1.loc['buy', stock] < 0 and abs((df1.loc['buy', stock]/ df1.loc['price', stock])) > 1: 
        print('true')
        r.order_sell_market(stock, abs(round((df1.loc['buy', stock]/ df1.loc['price', stock]),0)))
